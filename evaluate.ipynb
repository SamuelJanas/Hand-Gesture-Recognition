# %%
import torch
from model.CustomCNN import CustomResNet18
import matplotlib.pyplot as plt
import torchvision.transforms.functional as TF


import os
import random
from PIL import Image
import numpy as np

checkpoint = torch.load('checkpoints/resnet18_best_acc.pth')
model = CustomResNet18()
model.load_state_dict(checkpoint['state_dict'])
model.eval()
label_names = ['call', 'dislike', 'fist', 'four', 'like', 'mute', 'ok', 'one', 'palm', 'peace', 'peace_inverted', 'rock', 'stop', 'stop_inverted', 'three', 'three2', 'two_up', 'two_up_inverted']
# Out:
# c:\Users\samue\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def load_random_image(dir='ok'):
    path = f'data/train/{dir}'
    image = Image.open(path + '/' + random.choice(os.listdir(path)))
    x = TF.to_tensor(image)
    x = TF.resize(x, (400, 400), antialias=True)
    x.unsqueeze_(0)
    return x

# %%
# dont display warnings 
import warnings
warnings.filterwarnings("ignore")

# %%
for _ in range(10):
    image = load_random_image(dir="three")
    print(image)
    output = model(image)
    predicted_class = label_names[torch.argmax(output).item()]
    print(predicted_class)
# Out:
# tensor([[[[0.9665, 0.9594, 0.9526,  ..., 0.6945, 0.7013, 0.7106],
#           [0.9784, 0.9704, 0.9625,  ..., 0.6910, 0.6947, 0.7011],
#           [0.9833, 0.9769, 0.9676,  ..., 0.6859, 0.6814, 0.6814],
#           ...,
#           [0.2374, 0.2257, 0.2181,  ..., 0.8863, 0.8863, 0.8863],
#           [0.2304, 0.2188, 0.2111,  ..., 0.8863, 0.8863, 0.8863],
#           [0.2261, 0.2148, 0.2082,  ..., 0.8863, 0.8863, 0.8863]],
#
#          [[0.9861, 0.9790, 0.9722,  ..., 0.7063, 0.7131, 0.7223],
#           [0.9967, 0.9900, 0.9821,  ..., 0.7028, 0.7065, 0.7129],
#           [1.0000, 0.9965, 0.9872,  ..., 0.6977, 0.6932, 0.6932],
#           ...,
#           [0.2884, 0.2767, 0.2691,  ..., 0.8275, 0.8275, 0.8275],
#           [0.2814, 0.2698, 0.2620,  ..., 0.8275, 0.8275, 0.8275],
#           [0.2771, 0.2658, 0.2592,  ..., 0.8275, 0.8275, 0.8275]],
#
#          [[0.9626, 0.9555, 0.9487,  ..., 0.6788, 0.6856, 0.6949],
#           [0.9744, 0.9665, 0.9586,  ..., 0.6753, 0.6791, 0.6854],
#           [0.9793, 0.9730, 0.9637,  ..., 0.6702, 0.6658, 0.6657],
#           ...,
#           [0.3629, 0.3512, 0.3436,  ..., 0.7137, 0.7137, 0.7137],
#           [0.3559, 0.3443, 0.3366,  ..., 0.7137, 0.7137, 0.7137],
#           [0.3516, 0.3403, 0.3337,  ..., 0.7137, 0.7137, 0.7137]]]])
# three
# tensor([[[[0.9315, 0.9361, 0.9401,  ..., 0.8841, 0.8720, 0.8496],
#           [0.9361, 0.9408, 0.9429,  ..., 0.8558, 0.8398, 0.8250],
#           [0.9401, 0.9429, 0.9466,  ..., 0.8307, 0.8229, 0.8246],
#           ...,
#           [0.8574, 0.8603, 0.8603,  ..., 0.8151, 0.7960, 0.7900],
#           [0.8599, 0.8618, 0.8606,  ..., 0.8221, 0.7933, 0.7905],
#           [0.8591, 0.8581, 0.8560,  ..., 0.8487, 0.8087, 0.8023]],
#
#          [[0.9354, 0.9401, 0.9440,  ..., 0.8881, 0.8759, 0.8536],
#           [0.9401, 0.9447, 0.9469,  ..., 0.8597, 0.8437, 0.8289],
#           [0.9440, 0.9469, 0.9506,  ..., 0.8347, 0.8269, 0.8285],
#           ...,
#           [0.8417, 0.8446, 0.8446,  ..., 0.8072, 0.7881, 0.7821],
#           [0.8442, 0.8461, 0.8449,  ..., 0.8143, 0.7854, 0.7827],
#           [0.8434, 0.8424, 0.8403,  ..., 0.8408, 0.8009, 0.7944]],
#
#          [[0.9158, 0.9187, 0.9205,  ..., 0.8332, 0.8167, 0.7908],
#           [0.9205, 0.9233, 0.9233,  ..., 0.8048, 0.7845, 0.7662],
#           [0.9244, 0.9255, 0.9270,  ..., 0.7798, 0.7676, 0.7658],
#           ...,
#           [0.8064, 0.8093, 0.8093,  ..., 0.7602, 0.7411, 0.7351],
#           [0.8089, 0.8108, 0.8096,  ..., 0.7672, 0.7384, 0.7356],
#           [0.8081, 0.8071, 0.8050,  ..., 0.7938, 0.7538, 0.7474]]]])
# three
# tensor([[[[0.7106, 0.7131, 0.7137,  ..., 0.9989, 0.9934, 0.9883],
#           [0.7098, 0.7116, 0.7137,  ..., 1.0000, 0.9988, 0.9978],
#           [0.7080, 0.7105, 0.7113,  ..., 0.9960, 0.9989, 1.0000],
#           ...,
#           [0.0299, 0.0306, 0.0338,  ..., 0.7868, 0.7851, 0.7829],
#           [0.0275, 0.0292, 0.0338,  ..., 0.7854, 0.7877, 0.7891],
#           [0.0275, 0.0292, 0.0338,  ..., 0.7825, 0.7902, 0.7971]],
#
#          [[0.7027, 0.7053, 0.7059,  ..., 0.9793, 0.9738, 0.9686],
#           [0.7020, 0.7037, 0.7059,  ..., 0.9804, 0.9802, 0.9800],
#           [0.7008, 0.7040, 0.7050,  ..., 0.9764, 0.9801, 0.9837],
#           ...,
#           [0.0064, 0.0070, 0.0103,  ..., 0.8387, 0.8350, 0.8300],
#           [0.0039, 0.0057, 0.0103,  ..., 0.8364, 0.8353, 0.8340],
#           [0.0039, 0.0057, 0.0103,  ..., 0.8335, 0.8369, 0.8403]],
#
#          [[0.6518, 0.6543, 0.6549,  ..., 0.8931, 0.8875, 0.8824],
#           [0.6475, 0.6492, 0.6514,  ..., 0.8976, 0.8974, 0.8972],
#           [0.6400, 0.6411, 0.6415,  ..., 0.8979, 0.9017, 0.9052],
#           ...,
#           [0.0064, 0.0070, 0.0103,  ..., 0.8987, 0.8945, 0.8891],
#           [0.0039, 0.0057, 0.0103,  ..., 0.9013, 0.9014, 0.9011],
#           [0.0039, 0.0057, 0.0103,  ..., 0.9002, 0.9057, 0.9108]]]])
# three
# tensor([[[[0.7098, 0.7098, 0.7118,  ..., 0.7647, 0.7647, 0.7647],
#           [0.7098, 0.7098, 0.7118,  ..., 0.7647, 0.7647, 0.7647],
#           [0.7098, 0.7098, 0.7118,  ..., 0.7647, 0.7647, 0.7647],
#           ...,
#           [0.1260, 0.1294, 0.1331,  ..., 0.8956, 0.8956, 0.8956],
#           [0.1298, 0.1297, 0.1294,  ..., 0.8980, 0.8980, 0.8980],
#           [0.1413, 0.1366, 0.1308,  ..., 0.8980, 0.8980, 0.8980]],
#
#          [[0.6745, 0.6745, 0.6765,  ..., 0.7176, 0.7176, 0.7176],
#           [0.6745, 0.6745, 0.6765,  ..., 0.7176, 0.7176, 0.7176],
#           [0.6745, 0.6745, 0.6765,  ..., 0.7176, 0.7176, 0.7176],
#           ...,
#           [0.1260, 0.1294, 0.1331,  ..., 0.8720, 0.8720, 0.8720],
#           [0.1298, 0.1297, 0.1294,  ..., 0.8745, 0.8745, 0.8745],
#           [0.1413, 0.1366, 0.1308,  ..., 0.8745, 0.8745, 0.8745]],
#
#          [[0.6157, 0.6157, 0.6176,  ..., 0.6627, 0.6627, 0.6627],
#           [0.6157, 0.6157, 0.6176,  ..., 0.6627, 0.6627, 0.6627],
#           [0.6157, 0.6157, 0.6176,  ..., 0.6627, 0.6627, 0.6627],
#           ...,
#           [0.1182, 0.1215, 0.1253,  ..., 0.7858, 0.7858, 0.7858],
#           [0.1220, 0.1218, 0.1216,  ..., 0.7882, 0.7882, 0.7882],
#           [0.1335, 0.1288, 0.1230,  ..., 0.7882, 0.7882, 0.7882]]]])
# three
# tensor([[[[0.1401, 0.1208, 0.1211,  ..., 0.5294, 0.5188, 0.4845],
#           [0.1374, 0.1204, 0.1222,  ..., 0.5231, 0.5131, 0.4897],
#           [0.1294, 0.1192, 0.1276,  ..., 0.5176, 0.5114, 0.4987],
#           ...,
#           [0.7691, 0.6681, 0.6321,  ..., 0.7529, 0.7500, 0.7476],
#           [0.7772, 0.6615, 0.5728,  ..., 0.7535, 0.7465, 0.7414],
#           [0.7740, 0.6372, 0.4855,  ..., 0.7539, 0.7447, 0.7362]],
#
#          [[0.0852, 0.0659, 0.0662,  ..., 0.4863, 0.4757, 0.4414],
#           [0.0825, 0.0655, 0.0673,  ..., 0.4799, 0.4700, 0.4465],
#           [0.0745, 0.0643, 0.0727,  ..., 0.4745, 0.4683, 0.4555],
#           ...,
#           [0.7976, 0.6960, 0.6581,  ..., 0.7020, 0.6990, 0.6966],
#           [0.8057, 0.6894, 0.5988,  ..., 0.7025, 0.6955, 0.6904],
#           [0.8025, 0.6651, 0.5115,  ..., 0.7030, 0.6937, 0.6852]],
#
#          [[0.0813, 0.0620, 0.0623,  ..., 0.4706, 0.4600, 0.4257],
#           [0.0785, 0.0616, 0.0634,  ..., 0.4643, 0.4543, 0.4309],
#           [0.0706, 0.0603, 0.0688,  ..., 0.4588, 0.4526, 0.4399],
#           ...,
#           [0.8572, 0.7487, 0.7031,  ..., 0.6784, 0.6755, 0.6731],
#           [0.8653, 0.7421, 0.6438,  ..., 0.6790, 0.6719, 0.6668],
#           [0.8620, 0.7178, 0.5565,  ..., 0.6794, 0.6702, 0.6617]]]])
# three
# tensor([[[[0.7895, 0.7547, 0.6116,  ..., 0.5236, 0.5218, 0.5532],
#           [0.7203, 0.7775, 0.7017,  ..., 0.5082, 0.5298, 0.5425],
#           [0.7017, 0.6839, 0.7400,  ..., 0.5138, 0.5336, 0.5187],
#           ...,
#           [0.1814, 0.1283, 0.1197,  ..., 0.4763, 0.4732, 0.4861],
#           [0.5120, 0.4424, 0.4128,  ..., 0.4740, 0.4591, 0.4718],
#           [0.3438, 0.4396, 0.5305,  ..., 0.4852, 0.4799, 0.4553]],
#
#          [[0.7934, 0.7586, 0.6156,  ..., 0.4844, 0.4848, 0.5179],
#           [0.7243, 0.7815, 0.7056,  ..., 0.4690, 0.4928, 0.5072],
#           [0.7057, 0.6878, 0.7439,  ..., 0.4746, 0.4966, 0.4834],
#           ...,
#           [0.1696, 0.1166, 0.1079,  ..., 0.4606, 0.4576, 0.4704],
#           [0.5046, 0.4350, 0.4054,  ..., 0.4605, 0.4456, 0.4582],
#           [0.3427, 0.4373, 0.5265,  ..., 0.4735, 0.4682, 0.4436]],
#
#          [[0.7385, 0.7037, 0.5607,  ..., 0.4491, 0.4538, 0.4904],
#           [0.6658, 0.7230, 0.6472,  ..., 0.4337, 0.4618, 0.4797],
#           [0.6429, 0.6250, 0.6812,  ..., 0.4393, 0.4656, 0.4559],
#           ...,
#           [0.2128, 0.1597, 0.1492,  ..., 0.4488, 0.4458, 0.4587],
#           [0.5412, 0.4716, 0.4398,  ..., 0.4444, 0.4295, 0.4421],
#           [0.3741, 0.4686, 0.5579,  ..., 0.4539, 0.4486, 0.4240]]]])
# three
# tensor([[[[0.5216, 0.5433, 0.5416,  ..., 0.7590, 0.7624, 0.7657],
#           [0.5266, 0.5374, 0.5346,  ..., 0.7625, 0.7606, 0.7590],
#           [0.5281, 0.5284, 0.5275,  ..., 0.7687, 0.7628, 0.7575],
#           ...,
#           [0.4181, 0.3746, 0.3736,  ..., 0.7388, 0.7389, 0.7412],
#           [0.4246, 0.3892, 0.3862,  ..., 0.7429, 0.7423, 0.7442],
#           [0.4284, 0.4021, 0.3985,  ..., 0.7540, 0.7426, 0.7341]],
#
#          [[0.3726, 0.3943, 0.3926,  ..., 0.4727, 0.4783, 0.4834],
#           [0.3776, 0.3884, 0.3856,  ..., 0.4763, 0.4765, 0.4767],
#           [0.3791, 0.3794, 0.3785,  ..., 0.4824, 0.4787, 0.4752],
#           ...,
#           [0.2259, 0.1825, 0.1815,  ..., 0.5976, 0.5977, 0.6001],
#           [0.2325, 0.1971, 0.1941,  ..., 0.6018, 0.6012, 0.6030],
#           [0.2362, 0.2100, 0.2063,  ..., 0.6129, 0.6015, 0.5929]],
#
#          [[0.2981, 0.3198, 0.3181,  ..., 0.3041, 0.3161, 0.3265],
#           [0.3031, 0.3139, 0.3111,  ..., 0.3076, 0.3143, 0.3198],
#           [0.3045, 0.3049, 0.3040,  ..., 0.3138, 0.3166, 0.3183],
#           ...,
#           [0.1004, 0.0570, 0.0560,  ..., 0.5035, 0.5036, 0.5059],
#           [0.1070, 0.0716, 0.0686,  ..., 0.5076, 0.5070, 0.5089],
#           [0.1107, 0.0845, 0.0809,  ..., 0.5187, 0.5073, 0.4988]]]])
# three
# tensor([[[[0.5469, 0.5221, 0.4891,  ..., 0.7358, 0.7415, 0.7469],
#           [0.5813, 0.5422, 0.4878,  ..., 0.7409, 0.7412, 0.7415],
#           [0.5894, 0.5498, 0.4921,  ..., 0.7461, 0.7409, 0.7358],
#           ...,
#           [0.7409, 0.7350, 0.7308,  ..., 0.7387, 0.7433, 0.7469],
#           [0.7443, 0.7459, 0.7432,  ..., 0.7366, 0.7400, 0.7424],
#           [0.7665, 0.7647, 0.7548,  ..., 0.7337, 0.7360, 0.7380]],
#
#          [[0.4058, 0.3845, 0.3558,  ..., 0.6221, 0.6277, 0.6332],
#           [0.4401, 0.4045, 0.3545,  ..., 0.6272, 0.6275, 0.6277],
#           [0.4482, 0.4122, 0.3588,  ..., 0.6324, 0.6272, 0.6221],
#           ...,
#           [0.6350, 0.6292, 0.6249,  ..., 0.6211, 0.6257, 0.6293],
#           [0.6384, 0.6400, 0.6373,  ..., 0.6189, 0.6223, 0.6247],
#           [0.6606, 0.6588, 0.6489,  ..., 0.6161, 0.6183, 0.6204]],
#
#          [[0.3509, 0.3331, 0.3087,  ..., 0.5672, 0.5728, 0.5783],
#           [0.3852, 0.3531, 0.3074,  ..., 0.5723, 0.5725, 0.5728],
#           [0.3933, 0.3608, 0.3117,  ..., 0.5775, 0.5723, 0.5672],
#           ...,
#           [0.5918, 0.5860, 0.5818,  ..., 0.5779, 0.5826, 0.5861],
#           [0.5953, 0.5969, 0.5942,  ..., 0.5758, 0.5792, 0.5816],
#           [0.6175, 0.6157, 0.6058,  ..., 0.5729, 0.5752, 0.5772]]]])
# three
# tensor([[[[0.9104, 0.9104, 0.9104,  ..., 0.6496, 0.6530, 0.6518],
#           [0.9474, 0.9474, 0.9474,  ..., 0.6571, 0.6572, 0.6550],
#           [0.9647, 0.9647, 0.9647,  ..., 0.6612, 0.6627, 0.6617],
#           ...,
#           [0.4363, 0.4403, 0.4441,  ..., 0.5177, 0.5069, 0.4948],
#           [0.4438, 0.4435, 0.4446,  ..., 0.5230, 0.5137, 0.5016],
#           [0.4528, 0.4486, 0.4453,  ..., 0.5322, 0.5230, 0.5109]],
#
#          [[0.9496, 0.9496, 0.9496,  ..., 0.6809, 0.6844, 0.6831],
#           [0.9813, 0.9813, 0.9813,  ..., 0.6849, 0.6851, 0.6828],
#           [0.9922, 0.9922, 0.9922,  ..., 0.6847, 0.6863, 0.6852],
#           ...,
#           [0.0677, 0.0717, 0.0755,  ..., 0.5138, 0.4965, 0.4791],
#           [0.0687, 0.0684, 0.0695,  ..., 0.5191, 0.5033, 0.4859],
#           [0.0724, 0.0682, 0.0649,  ..., 0.5283, 0.5126, 0.4952]],
#
#          [[0.9183, 0.9183, 0.9183,  ..., 0.6378, 0.6413, 0.6400],
#           [0.9517, 0.9517, 0.9517,  ..., 0.6435, 0.6437, 0.6414],
#           [0.9647, 0.9647, 0.9647,  ..., 0.6455, 0.6471, 0.6460],
#           ...,
#           [0.1383, 0.1423, 0.1461,  ..., 0.5060, 0.4865, 0.4674],
#           [0.1415, 0.1412, 0.1423,  ..., 0.5112, 0.4933, 0.4742],
#           [0.1469, 0.1428, 0.1394,  ..., 0.5205, 0.5026, 0.4834]]]])
# four
# tensor([[[[0.6539, 0.6659, 0.6745,  ..., 0.8196, 0.8196, 0.8196],
#           [0.6564, 0.6668, 0.6745,  ..., 0.8196, 0.8196, 0.8196],
#           [0.6588, 0.6680, 0.6745,  ..., 0.8196, 0.8196, 0.8196],
#           ...,
#           [0.4135, 0.4320, 0.4474,  ..., 0.6095, 0.5753, 0.5502],
#           [0.4321, 0.4446, 0.4554,  ..., 0.4771, 0.4392, 0.4155],
#           [0.4638, 0.4632, 0.4595,  ..., 0.3513, 0.3281, 0.3145]],
#
#          [[0.6421, 0.6488, 0.6510,  ..., 0.8157, 0.8157, 0.8157],
#           [0.6447, 0.6498, 0.6510,  ..., 0.8157, 0.8157, 0.8157],
#           [0.6470, 0.6510, 0.6510,  ..., 0.8157, 0.8157, 0.8157],
#           ...,
#           [0.3429, 0.3632, 0.3808,  ..., 0.5703, 0.5382, 0.5149],
#           [0.3615, 0.3757, 0.3887,  ..., 0.4357, 0.4012, 0.3802],
#           [0.3932, 0.3944, 0.3928,  ..., 0.3081, 0.2893, 0.2792]],
#
#          [[0.5833, 0.5953, 0.6039,  ..., 0.7961, 0.7961, 0.7961],
#           [0.5858, 0.5962, 0.6039,  ..., 0.7961, 0.7961, 0.7961],
#           [0.5882, 0.5974, 0.6039,  ..., 0.7961, 0.7961, 0.7961],
#           ...,
#           [0.2645, 0.2883, 0.3102,  ..., 0.5350, 0.5029, 0.4796],
#           [0.2831, 0.3008, 0.3181,  ..., 0.4069, 0.3712, 0.3492],
#           [0.3147, 0.3195, 0.3222,  ..., 0.2846, 0.2636, 0.2517]]]])
# three
